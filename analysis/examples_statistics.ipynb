# %% [markdown]
# # BasqueTrivia Examples and Statistics

# %%
from datasets import load_dataset

basquetrivia_en = load_dataset("HiTZ/BasqueTrivia", "en", split="test")

basquetrivia_eu = load_dataset("HiTZ/BasqueTrivia", "eu", split="test")

# %%
basquetrivia_en[0]
# Out:
# {'id': 0,
#  'category': 'Geografia eta Historia',
#  'group': 'Gai orokorrak',
#  'difficulty': 3,
#  'question': 'Who was imprisoned in 1964?',
#  'answer': 0,
#  'candidates': ['Nelson Mandela', 'Mumia Abu Jamal', 'Charles Ghankay']}

# %% [markdown]
# ## Examples

# %%
# extract one example from each category and group fields
import pandas as pd
def extract_examples(basquetrivia):
    examples = []
    seen = set()
    for ex in basquetrivia:
        category_group = (ex["category"], ex["group"])
        if category_group not in seen:
            examples.append(ex)
            seen.add(tuple(category_group))
    
    examples_df = pd.DataFrame(examples)
    # order by category and group
    examples_df = examples_df.sort_values(["category", "group"])
    return examples_df

# %%
examples_en = extract_examples(basquetrivia_en)
pd.set_option('display.max_colwidth', None)
examples_en
# Out:
#     id                 category          group  difficulty  \
# 10  16   Euskara eta literatura   Euskal gaiak           1
# 3    3   Euskara eta literatura  Gai orokorrak           3
# 2    2   Geografia eta Historia   Euskal gaiak           1
# 0    0   Geografia eta Historia  Gai orokorrak           3
# 9   15    Gizartea eta ohiturak   Euskal gaiak           3
# 13  29    Gizartea eta ohiturak  Gai orokorrak           3
# 5    8     Kirola eta aisialdia   Euskal gaiak           1
# 8   13     Kirola eta aisialdia  Gai orokorrak           2
# 11  21        Kultura eta artea   Euskal gaiak           3
# 6    9        Kultura eta artea  Gai orokorrak           2
# 7   10        Musika eta dantza   Euskal gaiak           1
# 15  48        Musika eta dantza  Gai orokorrak           2
# 14  36  Zientzia eta teknologia   Euskal gaiak           1
# 4    6  Zientzia eta teknologia  Gai orokorrak           3
# 1    1   Zinema eta ikuskizunak   Euskal gaiak           1
# 12  26   Zinema eta ikuskizunak  Gai orokorrak           2
#
#                                                                                                                                            question  \
# 10                                                                                                   What does the "Karmel" magazine specialize in?
# 3                                                                            How many members make up the Euskararen Gizarte Erakundeen Kontseilua?
# 2                                                                                                                                  Where's Atxondo?
# 0                                                                                                                       Who was imprisoned in 1964?
# 9                                                                                        Which of the following is a Basque Government institution?
# 13  In the first general laws we know (those of the king of Babylon in the eighteenth century BC), was there any distinction between women and men?
# 5                                                                                                                     Where was Julian Retegi born?
# 8                                                                                                                     Where's the O'Connell Bridge?
# 11                                                                                         Who built the Gaztelu Berria or Château-Neuf in Bayonne?
# 6                                                                                                         When did the Titanic Belfast Museum open?
# 7                                                                                                  Where did the dance called "Dantzari" originate?
# 15                                                                                              Who wrote the soundtrack for the James Bond series?
# 14                                                                                                Which town in Biscay is associated with dynamite?
# 4                                                                                                        What is the scientific name for daltonism?
# 1                                                                         What's the name of the film based on Bernardo Atxaga's novel "Obabakoak"?
# 12                                                                          What instrument did Marilyn Monroe play in the film "Some like it hot"?
#
#     answer  \
# 10       1
# 3        1
# 2        0
# 0        0
# 9        2
# 13       2
# 5        1
# 8        1
# 11       0
# 6        0
# 7        2
# 15       0
# 14       1
# 4        2
# 1        1
# 12       2
#
#                                                                                                                                                           candidates
# 10                                                                            [Bertsolarism, Basque culture in the past and the present, The life of the Carmelites]
# 3                                                                                                                                                       [40, 46, 50]
# 2                                                                                                                               [In Biscay, In Gipuzkoa, In Navarre]
# 0                                                                                                                 [Nelson Mandela, Mumia Abu Jamal, Charles Ghankay]
# 9                                                                                                                                                   [IKA, AEK, HABE]
# 13  [No, they both had the same rights and obligations., Yes, women were subject to men and had no rights., Yes, but women also had certain rights and obligations.]
# 5                                                                                                                                            [Areso, Eratsun, Eraso]
# 8                                                                                                                                   [In London, In Dublin, In Milan]
# 11                                                                                                                            [The English, The French, The Spanish]
# 6                                                                                                                                        [In 2012, In 2005, In 2002]
# 7                                                                                                [In the Busturia area, In the Enkarterri area, In the Durango area]
# 15                                                                                                                        [John Barry, Henry Mancini, John Williams]
# 14                                                                                                                                        [Leioa, Galdakao, Erandio]
# 4                                                                                                                       [Chondrostoma, Chromatosis, Dyschromatopsia]
# 1                                                                                                                        ["Obabakoak", "Obaba", "Obabako istorioak"]
# 12                                                                                                                           [The Harp, The Didgeridoo, The Ukulele]

# %%
examples_eu = extract_examples(basquetrivia_eu)
examples_eu
# Out:
#     id                 category          group  difficulty  \
# 10  16   Euskara eta literatura   Euskal gaiak           1
# 3    3   Euskara eta literatura  Gai orokorrak           3
# 2    2   Geografia eta Historia   Euskal gaiak           1
# 0    0   Geografia eta Historia  Gai orokorrak           3
# 9   15    Gizartea eta ohiturak   Euskal gaiak           3
# 13  29    Gizartea eta ohiturak  Gai orokorrak           3
# 5    8     Kirola eta aisialdia   Euskal gaiak           1
# 8   13     Kirola eta aisialdia  Gai orokorrak           2
# 11  21        Kultura eta artea   Euskal gaiak           3
# 6    9        Kultura eta artea  Gai orokorrak           2
# 7   10        Musika eta dantza   Euskal gaiak           1
# 15  48        Musika eta dantza  Gai orokorrak           2
# 14  36  Zientzia eta teknologia   Euskal gaiak           1
# 4    6  Zientzia eta teknologia  Gai orokorrak           3
# 1    1   Zinema eta ikuskizunak   Euskal gaiak           1
# 12  26   Zinema eta ikuskizunak  Gai orokorrak           2
#
#                                                                                                                                               question  \
# 10                                                                                                                  Zertaz ari da "Karmel" aldizkaria?
# 3                                                                                  Zenbat kidek osatzen dute Euskararen Gizarte Erakundeen Kontseilua?
# 2                                                                                                                                    Non dago Atxondo?
# 0                                                                                                                       Nor kartzelaratu zuten 1964an?
# 9                                                                                                       Hauetako zein dago Eusko Jaurlaritzaren menpe?
# 13  Ezagutzen dugun lehenengo legedi orokorrean (K.a. XVIII. mendeko Babiloniako erregearena), bereizketarik al zegoen emakume eta gizonezkoen artean?
# 5                                                                                                                          Non jaio zen Julian Retegi?
# 8                                                                                                                           Non dago O ́Connell zubia?
# 11                                                                                                      Nortzuek eraiki zuten Baionako Gaztelu Berria?
# 6                                                                                                             Noiz ireki zuten Titanic Belfast Museoa?
# 7                                                                                                  Nongo dantza da jatorriz "dantzari" izeneko dantza?
# 15                                                                                                    Nork idatzi zuen James Bond serieko soinu-banda?
# 14                                                                                                    Bizkaiko zer udalerri dago lotuta dinamitarekin?
# 4                                                                                                             Zein da daltonismoaren izen zientifikoa?
# 1                                                                        Nola du izena Bernardo Atxagaren "Obabakoak" eleberrian oinarritutako filmak?
# 12                                    "Some like it hot" filmean (gaztelaniaz, "Con faldas y a lo loco"), zer instrumentu jotzen zuen Marilyn Monroek?
#
#     answer  \
# 10       1
# 3        1
# 2        0
# 0        0
# 9        2
# 13       2
# 5        1
# 8        1
# 11       0
# 6        0
# 7        2
# 15       0
# 14       1
# 4        2
# 1        1
# 12       2
#
#                                                                                                                                                                                                     candidates
# 10                                                                                                                               [Bertsolaritzaz, Lehengo eta gaurko euskal kulturaz, Karmeldarren bizimoduaz]
# 3                                                                                                                                                                                             [40k, 46k, 50ek]
# 2                                                                                                                                                                             [Bizkaian, Gipuzkoan, Nafarroan]
# 0                                                                                                                                                           [Nelson Mandela, Mumia Abu Jamal, Charles Ghankay]
# 9                                                                                                                                                                                             [IKA, AEK, HABE]
# 13  [Ez, biek eskubide eta betebehar beretsuak zituzten, Bai, emakumeak gizonaren menpean bizi behar zuen eta ez zuen inolako eskubiderik, Bai, baina emakumeek ere bazituzten zenbait eskubide eta betebehar]
# 5                                                                                                                                                                                  [Areson, Eratsunen, Erason]
# 8                                                                                                                                                                               [Londresen, Dublinen, Milanen]
# 11                                                                                                                                                                         [Ingelesek, Frantsesek, Espainolek]
# 6                                                                                                                                                                                    [2012an, 2005ean, 2002an]
# 7                                                                                                                                                            [Busturialdekoa, Enkarterrietakoa, Durangaldekoa]
# 15                                                                                                                                                           [John Barry-k, Henry Mancini-k, John Williams-ek]
# 14                                                                                                                                                                                  [Leioa, Galdakao, Erandio]
# 4                                                                                                                                                                   [Chondrostoma, Kromotosia, Diskromatopsia]
# 1                                                                                                                                                                  ["Obabakoak", "Obaba", "Obabako istorioak"]
# 12                                                                                                                                                                                 [Arpa, Didgeridoo, Ukelele]

# %% [markdown]
# ## Statistics

# %%
# calculate statistics from the dataset:
# number of examples per category, group and difficulty, similar to how above examples where extracted
# question length, candidate answers length

from collections import defaultdict
def calculate_statistics(basquetrivia):
    # number of examples per category and group
    stats = defaultdict(lambda: defaultdict(int))
    for ex in basquetrivia:
        stats[ex["category"]][ex["group"]] += 1
        
    # number of examples per category, group and difficulty
    stats_difficulty = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    for ex in basquetrivia:
        stats_difficulty[ex["category"]][ex["group"]][ex["difficulty"]] += 1
    
    # average len of questions and candidates
    stats_len = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    for ex in basquetrivia:
        stats_len[ex["category"]][ex["group"]]["question"] += len(ex["question"])
        for candidate in ex["candidates"]:
            stats_len[ex["category"]][ex["group"]]["candidates"] += len(candidate)
        
    # divide by number of examples
    for category, groups in stats_len.items():
        for group, lengths in groups.items():
            for key, value in lengths.items():
                if key == "question":
                    stats_len[category][group][key] = round(value / stats[category][group], 1)
                else: 
                    stats_len[category][group][key] = round(value / (stats[category][group]* 3), 1)
                    
    # convert stats to a dataframe with the same structure as the examples
    stats_df = []
    for category, groups in stats.items():
        for group, items in groups.items():
            stats_df.append({"category": category, "group": group, "items": items})
            # Add difficulty statistics
            for difficulty, count in stats_difficulty[category][group].items():
                stats_df[-1][difficulty] = count
            # Add length statistics
            stats_df[-1].update(stats_len[category][group])

    stats_df = pd.DataFrame(stats_df)
    stats_df = stats_df.sort_values(["category", "group"])
    
    return stats_df

stats_en = calculate_statistics(basquetrivia_en)

# %%
stats_en
# Out:
#                    category          group  items    3    2    1  question  \
# 5    Euskara eta literatura   Euskal gaiak    305  112  103   90      55.9
# 4    Euskara eta literatura  Gai orokorrak    310  111  108   91      53.3
# 1    Geografia eta Historia   Euskal gaiak    300   80  110  110      48.9
# 0    Geografia eta Historia  Gai orokorrak    300   80  110  110      43.0
# 14    Gizartea eta ohiturak   Euskal gaiak    289   78  108  103      60.2
# 15    Gizartea eta ohiturak  Gai orokorrak    298   79  109  110      51.1
# 8      Kirola eta aisialdia   Euskal gaiak    296   80  109  107      47.5
# 9      Kirola eta aisialdia  Gai orokorrak    303   80  110  113      43.3
# 11        Kultura eta artea   Euskal gaiak    295   80  110  105      43.5
# 10        Kultura eta artea  Gai orokorrak    286   80  108   98      40.7
# 12        Musika eta dantza   Euskal gaiak    289   80  102  107      49.0
# 13        Musika eta dantza  Gai orokorrak    300   80  110  110      43.4
# 7   Zientzia eta teknologia   Euskal gaiak    292   79  108  105      63.3
# 6   Zientzia eta teknologia  Gai orokorrak    296   79  109  108      53.0
# 2    Zinema eta ikuskizunak   Euskal gaiak    298   79  109  110      67.1
# 3    Zinema eta ikuskizunak  Gai orokorrak    299   80  110  109      55.8
#
#     candidates
# 5         16.9
# 4         15.7
# 1         12.8
# 0         10.3
# 14        16.1
# 15        18.0
# 8         11.7
# 9         10.3
# 11        11.5
# 10         9.1
# 12        12.5
# 13        10.8
# 7         12.5
# 6         11.0
# 2         16.3
# 3         12.4

# %%
stats_eu = calculate_statistics(basquetrivia_eu)

# %%
stats_eu
# Out:
#                    category          group  items    3    2    1  question  \
# 5    Euskara eta literatura   Euskal gaiak    305  112  103   90      51.0
# 4    Euskara eta literatura  Gai orokorrak    310  111  108   91      51.1
# 1    Geografia eta Historia   Euskal gaiak    300   80  110  110      44.4
# 0    Geografia eta Historia  Gai orokorrak    300   80  110  110      43.7
# 14    Gizartea eta ohiturak   Euskal gaiak    289   78  108  103      53.7
# 15    Gizartea eta ohiturak  Gai orokorrak    298   79  109  110      50.4
# 8      Kirola eta aisialdia   Euskal gaiak    296   80  109  107      42.6
# 9      Kirola eta aisialdia  Gai orokorrak    303   80  110  113      43.0
# 11        Kultura eta artea   Euskal gaiak    295   80  110  105      39.5
# 10        Kultura eta artea  Gai orokorrak    286   80  108   98      38.1
# 12        Musika eta dantza   Euskal gaiak    289   80  102  107      45.8
# 13        Musika eta dantza  Gai orokorrak    300   80  110  110      41.6
# 7   Zientzia eta teknologia   Euskal gaiak    292   79  108  105      60.0
# 6   Zientzia eta teknologia  Gai orokorrak    296   79  109  108      54.0
# 2    Zinema eta ikuskizunak   Euskal gaiak    298   79  109  110      65.2
# 3    Zinema eta ikuskizunak  Gai orokorrak    299   80  110  109      59.3
#
#     candidates
# 5         16.7
# 4         16.0
# 1         12.1
# 0         11.0
# 14        14.9
# 15        18.6
# 8         10.7
# 9         10.5
# 11        10.2
# 10         9.6
# 12        13.0
# 13        11.6
# 7         12.7
# 6         11.3
# 2         16.7
# 3         13.5

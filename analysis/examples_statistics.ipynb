# %% [markdown]
# # BasqueTrivia Examples and Statistics

# %%
from datasets import load_dataset

basquetrivia_en = load_dataset("HiTZ/BasqueTrivia", "en", split="test")

basquetrivia_eu = load_dataset("HiTZ/BasqueTrivia", "eu", split="test")

# %%
basquetrivia_en[0]
# Out:
# {'id': 0,
#  'category': 'Geografia eta Historia',
#  'group': 'Gai orokorrak',
#  'difficulty': 3,
#  'question': 'Who was imprisoned in 1964?',
#  'answer': 0,
#  'candidates': ['Nelson Mandela', 'Mumia Abu Jamal', 'Charles Ghankay']}

# %% [markdown]
# ## Examples

# %%
# extract one example from each category and group fields
import pandas as pd
def extract_examples(basquetrivia):
    examples = []
    seen = set()
    for ex in basquetrivia:
        category_group = (ex["category"], ex["group"])
        if category_group not in seen:
            examples.append(ex)
            seen.add(tuple(category_group))
    
    examples_df = pd.DataFrame(examples)
    # order by category and group
    examples_df = examples_df.sort_values(["category", "group"])
    return examples_df

# %%
examples_en = extract_examples(basquetrivia_en)
examples_en
# display dataframe withouth truncating text
pd.set_option('display.max_colwidth', None)
examples_en
# Out:
#     id                 category          group  difficulty  \
# 10  16   Euskara eta literatura   Euskal gaiak           1
# 3    3   Euskara eta literatura  Gai orokorrak           3
# 2    2   Geografia eta Historia   Euskal gaiak           1
# 0    0   Geografia eta Historia  Gai orokorrak           3
# 9   15    Gizartea eta ohiturak   Euskal gaiak           3
# 13  29    Gizartea eta ohiturak  Gai orokorrak           3
# 5    8     Kirola eta aisialdia   Euskal gaiak           1
# 8   13     Kirola eta aisialdia  Gai orokorrak           2
# 11  21        Kultura eta artea   Euskal gaiak           3
# 6    9        Kultura eta artea  Gai orokorrak           2
# 7   10        Musika eta dantza   Euskal gaiak           1
# 15  48        Musika eta dantza  Gai orokorrak           2
# 14  36  Zientzia eta teknologia   Euskal gaiak           1
# 4    6  Zientzia eta teknologia  Gai orokorrak           3
# 1    1   Zinema eta ikuskizunak   Euskal gaiak           1
# 12  26   Zinema eta ikuskizunak  Gai orokorrak           2
#
#                                                                                                                                            question  \
# 10                                                                                                   What does the "Karmel" magazine specialize in?
# 3                                                                            How many members make up the Euskararen Gizarte Erakundeen Kontseilua?
# 2                                                                                                                                  Where's Atxondo?
# 0                                                                                                                       Who was imprisoned in 1964?
# 9                                                                                        Which of the following is a Basque Government institution?
# 13  In the first general laws we know (those of the king of Babylon in the eighteenth century BC), was there any distinction between women and men?
# 5                                                                                                                     Where was Julian Retegi born?
# 8                                                                                                                     Where's the O'Connell Bridge?
# 11                                                                                         Who built the Gaztelu Berria or Château-Neuf in Bayonne?
# 6                                                                                                         When did the Titanic Belfast Museum open?
# 7                                                                                                  Where did the dance called "Dantzari" originate?
# 15                                                                                              Who wrote the soundtrack for the James Bond series?
# 14                                                                                                Which town in Biscay is associated with dynamite?
# 4                                                                                                        What is the scientific name for daltonism?
# 1                                                                         What's the name of the film based on Bernardo Atxaga's novel "Obabakoak"?
# 12                                                                          What instrument did Marilyn Monroe play in the film "Some like it hot"?
#
#     answer  \
# 10       1
# 3        1
# 2        0
# 0        0
# 9        2
# 13       2
# 5        1
# 8        1
# 11       0
# 6        0
# 7        2
# 15       0
# 14       1
# 4        2
# 1        1
# 12       2
#
#                                                                                                                                                           candidates
# 10                                                                            [Bertsolarism, Basque culture in the past and the present, The life of the Carmelites]
# 3                                                                                                                                                       [40, 46, 50]
# 2                                                                                                                               [In Biscay, In Gipuzkoa, In Navarre]
# 0                                                                                                                 [Nelson Mandela, Mumia Abu Jamal, Charles Ghankay]
# 9                                                                                                                                                   [IKA, AEK, HABE]
# 13  [No, they both had the same rights and obligations., Yes, women were subject to men and had no rights., Yes, but women also had certain rights and obligations.]
# 5                                                                                                                                            [Areso, Eratsun, Eraso]
# 8                                                                                                                                   [In London, In Dublin, In Milan]
# 11                                                                                                                            [The English, The French, The Spanish]
# 6                                                                                                                                        [In 2012, In 2005, In 2002]
# 7                                                                                                [In the Busturia area, In the Enkarterri area, In the Durango area]
# 15                                                                                                                        [John Barry, Henry Mancini, John Williams]
# 14                                                                                                                                        [Leioa, Galdakao, Erandio]
# 4                                                                                                                       [Chondrostoma, Chromatosis, Dyschromatopsia]
# 1                                                                                                                        ["Obabakoak", "Obaba", "Obabako istorioak"]
# 12                                                                                                                           [The Harp, The Didgeridoo, The Ukulele]

# %%
examples_eu = extract_examples(basquetrivia_eu)
examples_eu
# Out:
#     id                 category          group  difficulty  \
# 10  16   Euskara eta literatura   Euskal gaiak           1
# 3    3   Euskara eta literatura  Gai orokorrak           3
# 2    2   Geografia eta Historia   Euskal gaiak           1
# 0    0   Geografia eta Historia  Gai orokorrak           3
# 9   15    Gizartea eta ohiturak   Euskal gaiak           3
# 13  29    Gizartea eta ohiturak  Gai orokorrak           3
# 5    8     Kirola eta aisialdia   Euskal gaiak           1
# 8   13     Kirola eta aisialdia  Gai orokorrak           2
# 11  21        Kultura eta artea   Euskal gaiak           3
# 6    9        Kultura eta artea  Gai orokorrak           2
# 7   10        Musika eta dantza   Euskal gaiak           1
# 15  48        Musika eta dantza  Gai orokorrak           2
# 14  36  Zientzia eta teknologia   Euskal gaiak           1
# 4    6  Zientzia eta teknologia  Gai orokorrak           3
# 1    1   Zinema eta ikuskizunak   Euskal gaiak           1
# 12  26   Zinema eta ikuskizunak  Gai orokorrak           2
#
#                                              question  answer  \
# 10                 Zertaz ari da "Karmel" aldizkaria?       1
# 3   Zenbat kidek osatzen dute Euskararen Gizarte E...       1
# 2                                   Non dago Atxondo?       0
# 0                      Nor kartzelaratu zuten 1964an?       0
# 9      Hauetako zein dago Eusko Jaurlaritzaren menpe?       2
# 13  Ezagutzen dugun lehenengo legedi orokorrean (K...       2
# 5                         Non jaio zen Julian Retegi?       1
# 8                          Non dago O ́Connell zubia?       1
# 11     Nortzuek eraiki zuten Baionako Gaztelu Berria?       0
# 6            Noiz ireki zuten Titanic Belfast Museoa?       0
# 7   Nongo dantza da jatorriz "dantzari" izeneko da...       2
# 15   Nork idatzi zuen James Bond serieko soinu-banda?       0
# 14   Bizkaiko zer udalerri dago lotuta dinamitarekin?       1
# 4            Zein da daltonismoaren izen zientifikoa?       2
# 1   Nola du izena Bernardo Atxagaren "Obabakoak" e...       1
# 12  "Some like it hot" filmean (gaztelaniaz, "Con ...       2
#
#                                            candidates
# 10  [Bertsolaritzaz, Lehengo eta gaurko euskal kul...
# 3                                    [40k, 46k, 50ek]
# 2                    [Bizkaian, Gipuzkoan, Nafarroan]
# 0   [Nelson Mandela, Mumia Abu Jamal, Charles Ghan...
# 9                                    [IKA, AEK, HABE]
# 13  [Ez, biek eskubide eta betebehar beretsuak zit...
# 5                         [Areson, Eratsunen, Erason]
# 8                      [Londresen, Dublinen, Milanen]
# 11                [Ingelesek, Frantsesek, Espainolek]
# 6                           [2012an, 2005ean, 2002an]
# 7   [Busturialdekoa, Enkarterrietakoa, Durangaldekoa]
# 15  [John Barry-k, Henry Mancini-k, John Williams-ek]
# 14                         [Leioa, Galdakao, Erandio]
# 4          [Chondrostoma, Kromotosia, Diskromatopsia]
# 1         ["Obabakoak", "Obaba", "Obabako istorioak"]
# 12                        [Arpa, Didgeridoo, Ukelele]

# %% [markdown]
# ## Statistics

# %%
# calculate statistics from the dataset:
# number of examples per category, group and difficulty, similar to how above examples where extracted
# question length, candidate answers length

# Category Group Difficulty Items Question Candidate 1 Candidate 2 Candidate 3
# Geografia eta Historia Global Difficult 5169 100 15 15 15

from collections import defaultdict
def calculate_statistics(basquetrivia):
    # number of examples per category and group
    stats = defaultdict(lambda: defaultdict(int))
    for ex in basquetrivia:
        stats[ex["category"]][ex["group"]] += 1
        stats[ex["category"]][ex["difficulty"]] += 1
    
    # average len of questions and candidates
    stats_len = defaultdict(lambda: defaultdict(lambda: defaultdict(int)))
    for ex in basquetrivia:
        stats_len[ex["category"]][ex["group"]]["question"] += len(ex["question"])
        stats_len[ex["category"]][ex["group"]]["candidate_0"] += len(ex["candidates"][0])
        stats_len[ex["category"]][ex["group"]]["candidate_1"] += len(ex["candidates"][1])
        stats_len[ex["category"]][ex["group"]]["candidate_2"] += len(ex["candidates"][2])
        
    # divide by number of examples
    for category, groups in stats_len.items():
        for group, lengths in groups.items():
            for key, value in lengths.items():
                stats_len[category][group][key] = value / stats[category][group]
    
    return stats, stats_len

stats_en, stats_len_en = calculate_statistics(basquetrivia_en)

# %%
stats_en
# Out:
# defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>()>,
#             {'Geografia eta Historia': defaultdict(int,
#                          {'Gai orokorrak': 300,
#                           3: 160,
#                           'Euskal gaiak': 300,
#                           1: 220,
#                           2: 220}),
#              'Zinema eta ikuskizunak': defaultdict(int,
#                          {'Euskal gaiak': 298,
#                           1: 219,
#                           3: 159,
#                           2: 219,
#                           'Gai orokorrak': 299}),
#              'Euskara eta literatura': defaultdict(int,
#                          {'Gai orokorrak': 310,
#                           3: 223,
#                           'Euskal gaiak': 305,
#                           1: 181,
#                           2: 211}),
#              'Zientzia eta teknologia': defaultdict(int,
#                          {'Gai orokorrak': 296,
#                           3: 158,
#                           'Euskal gaiak': 292,
#                           1: 213,
#                           2: 217}),
#              'Kirola eta aisialdia': defaultdict(int,
#                          {'Euskal gaiak': 296,
#                           1: 220,
#                           2: 219,
#                           'Gai orokorrak': 303,
#                           3: 160}),
#              'Kultura eta artea': defaultdict(int,
#                          {'Gai orokorrak': 286,
#                           2: 218,
#                           'Euskal gaiak': 295,
#                           3: 160,
#                           1: 203}),
#              'Musika eta dantza': defaultdict(int,
#                          {'Euskal gaiak': 289,
#                           1: 217,
#                           'Gai orokorrak': 300,
#                           2: 212,
#                           3: 160}),
#              'Gizartea eta ohiturak': defaultdict(int,
#                          {'Euskal gaiak': 289,
#                           3: 157,
#                           1: 213,
#                           'Gai orokorrak': 298,
#                           2: 217})})

# %%
stats_len_en
# Out:
# defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>()>,
#             {'Geografia eta Historia': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Gai orokorrak': defaultdict(int,
#                                       {'question': 43.0,
#                                        'candidate_0': 10.163333333333334,
#                                        'candidate_1': 10.4,
#                                        'candidate_2': 10.326666666666666}),
#                           'Euskal gaiak': defaultdict(int,
#                                       {'question': 48.92,
#                                        'candidate_0': 12.506666666666666,
#                                        'candidate_1': 12.383333333333333,
#                                        'candidate_2': 13.57})}),
#              'Zinema eta ikuskizunak': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Euskal gaiak': defaultdict(int,
#                                       {'question': 67.1241610738255,
#                                        'candidate_0': 16.879194630872483,
#                                        'candidate_1': 15.835570469798657,
#                                        'candidate_2': 16.288590604026847}),
#                           'Gai orokorrak': defaultdict(int,
#                                       {'question': 55.79933110367893,
#                                        'candidate_0': 12.361204013377927,
#                                        'candidate_1': 12.100334448160535,
#                                        'candidate_2': 12.698996655518394})}),
#              'Euskara eta literatura': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Gai orokorrak': defaultdict(int,
#                                       {'question': 53.32258064516129,
#                                        'candidate_0': 15.790322580645162,
#                                        'candidate_1': 15.57741935483871,
#                                        'candidate_2': 15.719354838709677}),
#                           'Euskal gaiak': defaultdict(int,
#                                       {'question': 55.92131147540984,
#                                        'candidate_0': 17.0,
#                                        'candidate_1': 16.59672131147541,
#                                        'candidate_2': 17.2327868852459})}),
#              'Zientzia eta teknologia': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Gai orokorrak': defaultdict(int,
#                                       {'question': 53.0472972972973,
#                                        'candidate_0': 10.807432432432432,
#                                        'candidate_1': 11.10472972972973,
#                                        'candidate_2': 11.070945945945946}),
#                           'Euskal gaiak': defaultdict(int,
#                                       {'question': 63.284246575342465,
#                                        'candidate_0': 12.54109589041096,
#                                        'candidate_1': 12.41095890410959,
#                                        'candidate_2': 12.67123287671233})}),
#              'Kirola eta aisialdia': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Euskal gaiak': defaultdict(int,
#                                       {'question': 47.479729729729726,
#                                        'candidate_0': 11.614864864864865,
#                                        'candidate_1': 12.0,
#                                        'candidate_2': 11.358108108108109}),
#                           'Gai orokorrak': defaultdict(int,
#                                       {'question': 43.273927392739274,
#                                        'candidate_0': 10.207920792079207,
#                                        'candidate_1': 10.155115511551156,
#                                        'candidate_2': 10.633663366336634})}),
#              'Kultura eta artea': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Gai orokorrak': defaultdict(int,
#                                       {'question': 40.70979020979021,
#                                        'candidate_0': 9.108391608391608,
#                                        'candidate_1': 9.146853146853147,
#                                        'candidate_2': 9.090909090909092}),
#                           'Euskal gaiak': defaultdict(int,
#                                       {'question': 43.51186440677966,
#                                        'candidate_0': 11.376271186440677,
#                                        'candidate_1': 11.837288135593221,
#                                        'candidate_2': 11.179661016949153})}),
#              'Musika eta dantza': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Euskal gaiak': defaultdict(int,
#                                       {'question': 49.003460207612456,
#                                        'candidate_0': 12.487889273356402,
#                                        'candidate_1': 12.280276816608996,
#                                        'candidate_2': 12.653979238754324}),
#                           'Gai orokorrak': defaultdict(int,
#                                       {'question': 43.42333333333333,
#                                        'candidate_0': 10.79,
#                                        'candidate_1': 10.92,
#                                        'candidate_2': 10.593333333333334})}),
#              'Gizartea eta ohiturak': defaultdict(<function __main__.calculate_statistics.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'Euskal gaiak': defaultdict(int,
#                                       {'question': 60.15916955017301,
#                                        'candidate_0': 16.5121107266436,
#                                        'candidate_1': 15.314878892733564,
#                                        'candidate_2': 16.401384083044984}),
#                           'Gai orokorrak': defaultdict(int,
#                                       {'question': 51.147651006711406,
#                                        'candidate_0': 17.956375838926174,
#                                        'candidate_1': 17.936241610738254,
#                                        'candidate_2': 18.073825503355703})})})

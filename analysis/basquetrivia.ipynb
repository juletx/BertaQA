# %% [markdown]
# # BasqueTrivia Open Models Basque and English

# %%
import pandas as pd

def get_dataframe(model, size, config, version="v1"):
    if model == "llama-2":
        if size != 70:
            df = pd.read_json(f"../results/{model}/Llama-2-{size}b-hf/pretrained__meta-llama__Llama-2-{size}b-hf_basquetrivia_{config}.jsonl")
        else:
            df = pd.read_json(f"../results/{model}/Llama-2-{size}b-hf/pretrained__meta-llama__Llama-2-{size}b-hf,parallelize__True_basquetrivia_{config}.jsonl")
    if model == "latxa":
        if size != 70:
            df = pd.read_json(f"../results/{model}/latxa-{size}b-{version}/pretrained__HiTZ__latxa-{size}b-{version}_basquetrivia_{config}.jsonl")
        else:
            df = pd.read_json(f"../results/{model}/latxa-{size}b-{version}/pretrained__HiTZ__latxa-{size}b-{version},parallelize__True_basquetrivia_{config}.jsonl")
    if model == "qwen":
        if size != 72:
            df = pd.read_json(f"../results/{model}/Qwen1.5-{size}B/pretrained__Qwen__Qwen1.5-{size}B_basquetrivia_{config}.jsonl")
        else:
            df = pd.read_json(f"../results/{model}/Qwen1.5-{size}B/pretrained__Qwen__Qwen1.5-{size}B,parallelize__True_basquetrivia_{config}.jsonl")
    if model == "bloom":
        df = pd.read_json(f"../results/{model}/bloom-7b1/pretrained__bigscience__bloom-7b1,dtype__float16_basquetrivia_{config}.jsonl")
    if model == "xglm":
        df = pd.read_json(f"../results/{model}/xglm-7.5B/pretrained__facebook__xglm-7.5B,dtype__float16_basquetrivia_{config}.jsonl")
    if model == "mgpt":
        df = pd.read_json(f"../results/{model}/mGPT-13B/pretrained__ai-forever__mGPT-13B,dtype__float16_basquetrivia_{config}.jsonl")
    if model == "mistral":
        df = pd.read_json(f"../results/{model}/Mistral-7B-v0.1/pretrained__mistralai__Mistral-7B-v0.1_basquetrivia_{config}.jsonl")
    if model == "mixtral":
        df = pd.read_json(f"../results/mistral/Mixtral-8x7B-v0.1/pretrained__mistralai__Mixtral-8x7B-v0.1,parallelize__True_basquetrivia_{config}.jsonl")
    if model == "yi":
        if size != 34:
            df = pd.read_json(f"../results/{model}/Yi-{size}B/pretrained__01-ai__Yi-{size}B_basquetrivia_{config}.jsonl")
        else:
            df = pd.read_json(f"../results/{model}/Yi-{size}B/pretrained__01-ai__Yi-{size}B,parallelize__True_basquetrivia_{config}.jsonl")
    if model == "gemma":
        df = pd.read_json(f"../results/{model}/gemma-{size}b/pretrained__google__gemma-{size}b_basquetrivia_{config}.jsonl")
    return df

# %%
df_llama2_7b_basquetrivia_eu = get_dataframe("llama-2", 7, "eu")
df_llama2_13b_basquetrivia_eu = get_dataframe("llama-2", 13, "eu")
df_llama2_70b_basquetrivia_eu = get_dataframe("llama-2", 70, "eu")

df_llama2_7b_basquetrivia_en = get_dataframe("llama-2", 7, "en")
df_llama2_13b_basquetrivia_en = get_dataframe("llama-2", 13, "en")
df_llama2_70b_basquetrivia_en = get_dataframe("llama-2", 70, "en")

df_latxav1_7b_basquetrivia_eu = get_dataframe("latxa", 7, "eu", "v1")
df_latxav1_13b_basquetrivia_eu = get_dataframe("latxa", 13, "eu", "v1")
df_latxav1_70b_basquetrivia_eu = get_dataframe("latxa", 70, "eu", "v1")

df_latxav1_7b_basquetrivia_en = get_dataframe("latxa", 7, "en", "v1")
df_latxav1_13b_basquetrivia_en = get_dataframe("latxa", 13, "en", "v1")
df_latxav1_70b_basquetrivia_en = get_dataframe("latxa", 70, "en", "v1")

df_latxav11_7b_basquetrivia_eu = get_dataframe("latxa", 7, "eu", "v1.1")
df_latxav11_13b_basquetrivia_eu = get_dataframe("latxa", 13, "eu", "v1.1")
df_latxav11_70b_basquetrivia_eu = get_dataframe("latxa", 70, "eu", "v1.1")

df_latxav11_7b_basquetrivia_en = get_dataframe("latxa", 7, "en", "v1.1")
df_latxav11_13b_basquetrivia_en = get_dataframe("latxa", 13, "en", "v1.1")
df_latxav11_70b_basquetrivia_en = get_dataframe("latxa", 70, "en", "v1.1")

df_qwen15_7b_basquetrivia_eu = get_dataframe("qwen", 7, "eu")
df_qwen15_14b_basquetrivia_eu = get_dataframe("qwen", 14, "eu")
df_qwen15_72b_basquetrivia_eu = get_dataframe("qwen", 72, "eu")

df_qwen15_7b_basquetrivia_en = get_dataframe("qwen", 7, "en")
df_qwen15_14b_basquetrivia_en = get_dataframe("qwen", 14, "en")
df_qwen15_72b_basquetrivia_en = get_dataframe("qwen", 72, "en")

df_bloom_basquetrivia_eu = get_dataframe("bloom", 7, "eu")
df_xglm_basquetrivia_eu = get_dataframe("xglm", 7, "eu")
df_mgpt_basquetrivia_eu = get_dataframe("mgpt", 13, "eu")

df_bloom_basquetrivia_en = get_dataframe("bloom", 7, "en")
df_xglm_basquetrivia_en = get_dataframe("xglm", 7, "en")
df_mgpt_basquetrivia_en = get_dataframe("mgpt", 13, "en")

df_mistral_basquetrivia_eu = get_dataframe("mistral", 7, "eu")
df_mixtral_basquetrivia_eu = get_dataframe("mixtral", 45, "eu")

df_mistral_basquetrivia_en = get_dataframe("mistral", 7, "en")
df_mixtral_basquetrivia_en = get_dataframe("mixtral", 45, "en")

df_yi_6b_basquetrivia_en = get_dataframe("yi", 6, "en")
df_yi_9b_basquetrivia_en = get_dataframe("yi", 9, "en")
df_yi_34b_basquetrivia_en = get_dataframe("yi", 34, "en")

df_yi_6b_basquetrivia_eu = get_dataframe("yi", 6, "eu")
df_yi_9b_basquetrivia_eu = get_dataframe("yi", 9, "eu")
df_yi_34b_basquetrivia_eu = get_dataframe("yi", 34, "eu")

df_gemma_2b_basquetrivia_eu = get_dataframe("gemma", 2, "eu")
df_gemma_7b_basquetrivia_eu = get_dataframe("gemma", 7, "eu")

df_gemma_2b_basquetrivia_en = get_dataframe("gemma", 2, "en")
df_gemma_7b_basquetrivia_en = get_dataframe("gemma", 7, "en")

# %%
import matplotlib.pyplot as plt

def plot_eus_en_sizes(df_llama2_7b_basquetrivia_eu, df_llama2_13b_basquetrivia_eu, df_llama2_70b_basquetrivia_eu,df_llama2_7b_basquetrivia_en, df_llama2_13b_basquetrivia_en, df_llama2_70b_basquetrivia_en):
    merged = pd.DataFrame()
    merged["D=EU S=7"] = df_llama2_7b_basquetrivia_eu["acc"]
    merged["D=EU S=13"] = df_llama2_13b_basquetrivia_eu["acc"]
    merged["D=EU S=70"] = df_llama2_70b_basquetrivia_eu["acc"]
    merged["D=EN S=7"] = df_llama2_7b_basquetrivia_en["acc"]
    merged["D=EN S=13"] = df_llama2_13b_basquetrivia_en["acc"]
    merged["D=EN S=70"] = df_llama2_70b_basquetrivia_en["acc"]
    
    # plot average accuracy per model
    merged_mean = merged.mean()
    merged_mean.plot(kind="bar", rot=90, title="Average Accuracy per Model")
    display(pd.DataFrame((merged_mean* 100).round(2)))

    merged["group"] = df_llama2_7b_basquetrivia_eu["doc"].apply(lambda x: x["group"] if x["group"] != "Nazioarteko gaiak" else "Gai orokorrak")
    merged["difficulty"] = df_llama2_7b_basquetrivia_eu["doc"].apply(lambda x: x["difficulty"])
    merged["category"] = df_llama2_7b_basquetrivia_eu["doc"].apply(lambda x: x["category"])

    merged_grouped = merged.groupby("group").mean()
    merged_grouped_difficulty = merged.groupby("difficulty").mean()
    merged_grouped_category = merged.groupby("category").mean()
    # remove difficulty from merged_grouped and merged_grouped_category
    merged_grouped.drop("difficulty", axis=1, inplace=True)
    merged_grouped_category.drop("difficulty", axis=1, inplace=True)

    fig, axs = plt.subplots(1, 3, figsize=(20, 6))
    merged_grouped.plot(kind="bar", ax=axs[0], rot=0, title="Accuracy by Group")
    merged_grouped_difficulty.plot(kind="bar", ax=axs[2], rot=0, title="Accuracy by Difficulty")
    merged_grouped_category.plot(kind="bar", ax=axs[1], rot=90, title="Accuracy by Category")
    
    # multiply by 100 and round to 1 decimal place
    display((merged_grouped.T * 100).round(2))
    display((merged_grouped_difficulty.T * 100).round(2))
    display((merged_grouped_category.T * 100).round(2))
    
    # add plot that combines group and category
    merged_group_category = merged.groupby(["category", "group"]).mean()
    merged_group_category.drop("difficulty", axis=1, inplace=True)
    # merged_group_category.plot(kind="bar", rot=90, title="Accuracy by Category and Group")
    # make this plot bigger
    plt.gcf().set_size_inches(20, 6)
    display((merged_group_category.T * 100).round(2))

# %% [markdown]
# ## Llama 2

# %%
plot_eus_en_sizes(df_llama2_7b_basquetrivia_eu, df_llama2_13b_basquetrivia_eu, df_llama2_70b_basquetrivia_eu,df_llama2_7b_basquetrivia_en, df_llama2_13b_basquetrivia_en, df_llama2_70b_basquetrivia_en)
# Out:
#                0
# D=EU S=7   36.00
# D=EU S=13  38.96
# D=EU S=70  45.86
# D=EN S=7   53.01
# D=EN S=13  57.06
# D=EN S=70  63.50
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Latxa v1

# %%
plot_eus_en_sizes(df_latxav1_7b_basquetrivia_eu, df_latxav1_13b_basquetrivia_eu, df_latxav1_70b_basquetrivia_eu,df_latxav1_7b_basquetrivia_en, df_latxav1_13b_basquetrivia_en, df_latxav1_70b_basquetrivia_en)
# Out:
#                0
# D=EU S=7   50.25
# D=EU S=13  59.95
# D=EU S=70  65.92
# D=EN S=7   54.08
# D=EN S=13  61.35
# D=EN S=70  65.94
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Latxa v1.1

# %%
plot_eus_en_sizes(df_latxav11_7b_basquetrivia_eu, df_latxav11_13b_basquetrivia_eu, df_latxav11_70b_basquetrivia_eu,df_latxav11_7b_basquetrivia_en, df_latxav11_13b_basquetrivia_en, df_latxav11_70b_basquetrivia_en)
# Out:
#                0
# D=EU S=7   50.13
# D=EU S=13  62.87
# D=EU S=70  68.57
# D=EN S=7   50.50
# D=EN S=13  62.07
# D=EN S=70  68.15
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Qwen

# %%
plot_eus_en_sizes(df_qwen15_7b_basquetrivia_eu, df_qwen15_14b_basquetrivia_eu, df_qwen15_72b_basquetrivia_eu,df_qwen15_7b_basquetrivia_en, df_qwen15_14b_basquetrivia_en, df_qwen15_72b_basquetrivia_en)
# Out:
#                0
# D=EU S=7   41.08
# D=EU S=13  45.40
# D=EU S=70  53.07
# D=EN S=7   57.06
# D=EN S=13  60.39
# D=EN S=70  69.43
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Bloom, XGLM, mGPT

# %%
plot_eus_en_sizes(df_bloom_basquetrivia_eu, df_xglm_basquetrivia_eu, df_mgpt_basquetrivia_eu, df_bloom_basquetrivia_en, df_xglm_basquetrivia_en, df_mgpt_basquetrivia_en)
# Out:
#                0
# D=EU S=7   34.31
# D=EU S=13  33.89
# D=EU S=70  34.29
# D=EN S=7   33.62
# D=EN S=13  33.62
# D=EN S=70  34.88
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Mistral, Mixtral

# %%
plot_eus_en_sizes(df_mistral_basquetrivia_eu, df_mixtral_basquetrivia_eu, df_mixtral_basquetrivia_eu, df_mistral_basquetrivia_en, df_mixtral_basquetrivia_en, df_mixtral_basquetrivia_en)
# Out:
#                0
# D=EU S=7   44.22
# D=EU S=13  52.40
# D=EU S=70  52.40
# D=EN S=7   60.91
# D=EN S=13  70.16
# D=EN S=70  70.16
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Yi

# %%
plot_eus_en_sizes(df_yi_6b_basquetrivia_eu, df_yi_9b_basquetrivia_eu, df_yi_34b_basquetrivia_eu, df_yi_6b_basquetrivia_en, df_yi_9b_basquetrivia_en, df_yi_34b_basquetrivia_en)
# Out:
#                0
# D=EU S=7   42.22
# D=EU S=13  43.73
# D=EU S=70  50.78
# D=EN S=7   58.81
# D=EN S=13  59.52
# D=EN S=70  68.92
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...

# %% [markdown]
# ## Gemma

# %%
plot_eus_en_sizes(df_gemma_2b_basquetrivia_eu, df_gemma_7b_basquetrivia_eu, df_gemma_7b_basquetrivia_eu, df_gemma_2b_basquetrivia_en, df_gemma_7b_basquetrivia_en, df_gemma_7b_basquetrivia_en)
# Out:
#                0
# D=EU S=7   36.31
# D=EU S=13  53.93
# D=EU S=70  53.93
# D=EN S=7   47.20
# D=EN S=13  61.14
# D=EN S=70  61.14
# /tmp/ipykernel_2162689/3363575876.py:21: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped = merged.groupby("group").mean()
# /tmp/ipykernel_2162689/3363575876.py:22: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   merged_grouped_difficulty = merged.groupby("difficulty").mean()
# ...
